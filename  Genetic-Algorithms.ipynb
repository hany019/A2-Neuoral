# %%
import math
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Genetic Algorithm for Job Shop Scheduling Problem (JSSP)

# %%
def parse_dataset(file_path, instance_name):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    start_idx = -1
    for idx, line in enumerate(lines):
        if line.strip() == f"instance {instance_name}": 
            start_idx = idx  #If the line matches "instance {instance_name}", record its position (start_idx).

            break 

    if start_idx == -1: #If the instance isn’t found (start_idx remains -1), raise an error.
        raise ValueError(f"Instance {instance_name} not found in the dataset file.")

    job_data = []
    for idx in range(start_idx + 1, len(lines)):
        line = lines[idx].strip()
        if line.startswith('+') or line == "":
            continue
        try:
            job_count, machine_count = map(int, line.split())
            count_line_idx = idx
            break
        except ValueError:
            continue
    else:
        raise ValueError(f"Failed to find job and machine counts for instance {instance_name}.")

    for line in lines[count_line_idx + 1:]:
        line = line.strip()
        if line.startswith('+') or line == "":
            break
        tasks = list(map(int, line.split()))
        job = [(tasks[i], tasks[i + 1]) for i in range(0, len(tasks), 2)]
        job_data.append(job)  ##Look for the line that specifies the number of jobs  and machines.


    if len(job_data) != job_count:
        raise ValueError(f"Mismatch between declared job count ({job_count}) and parsed jobs ({len(job_data)}).")

    return job_data, machine_count

# %%
''''
# Define the data for the Job Shop Scheduling Problem (JSSP)
jobs_data = [
    [(0, 3), (1, 2), (2, 2)],  # Job 0
    [(0, 2), (2, 1), (1, 4)],  # Job 1
    [(1, 4), (2, 3)],          # Job 2
    [(0, 2), (1, 3), (2, 1)],  # Job 3
    [(1, 5), (2, 2), (0, 4)]   # Job 4
]

machines_count = 1 + max(task[0] for job in jobs_data for task in job)
all_machines = range(machines_count)
horizon = sum(task[1] for job in jobs_data for task in job) 

'''
# Out:
# "'\n# Define the data for the Job Shop Scheduling Problem (JSSP)\njobs_data = [\n    [(0, 3), (1, 2), (2, 2)],  # Job 0\n    [(0, 2), (2, 1), (1, 4)],  # Job 1\n    [(1, 4), (2, 3)],          # Job 2\n    [(0, 2), (1, 3), (2, 1)],  # Job 3\n    [(1, 5), (2, 2), (0, 4)]   # Job 4\n]\n\nmachines_count = 1 + max(task[0] for job in jobs_data for task in job)\nall_machines = range(machines_count)\nhorizon = sum(task[1] for job in jobs_data for task in job) \n\n"

# %%
# Checks if the sequence of tasks in the chromosome is valid
def is_valid_chromosome(chromosome, jobs_data):
    # Initialize a task tracker to keep track of the current task index for each job
    task_tracker = {job_id: 0 for job_id in range(len(jobs_data))}
    
    # Traverse each task in the given chromosome
    for job_id, (machine, duration) in chromosome:
        # Check if the task corresponds to the next expected task for this job
        # - task_tracker[job_id]: tracks the current task index for the job
        # - jobs_data[job_id]: list of tasks for the job
        if task_tracker[job_id] < len(jobs_data[job_id]) and jobs_data[job_id][task_tracker[job_id]] == (machine, duration):
            # If the task is valid and in the correct order, move to the next task for this job
            task_tracker[job_id] += 1
        else:
            # If the task does not match the expected task or is out of order, return False (invalid chromosome)
            return False
    
    # After traversing the entire chromosome, check if all jobs have completed their tasks
    # The condition ensures that the task tracker has reached the end for each job
    return all(task_tracker[job_id] == len(jobs_data[job_id]) for job_id in range(len(jobs_data)))

# %%
def repair_chromosome(chromosome, jobs_data):
    # Initialize a task tracker to keep track of the current task index for each job
    task_tracker = {job_id: 0 for job_id in range(len(jobs_data))}
    
    # Initialize machine_times to track the availability of each machine (when it's free to take the next task)
    machine_times = {machine: 0 for job in jobs_data for machine, _ in job}
    repaired_chromosome = []

    # Traverse the chromosome and add tasks while respecting job order
    for job_id, (machine, duration) in chromosome:
        # Check if the current task in the chromosome is valid for this job
        if task_tracker[job_id] < len(jobs_data[job_id]):
            expected_task = jobs_data[job_id][task_tracker[job_id]]

            # Ensure we follow the correct order for this job
            if (machine, duration) == expected_task:
                # Determine the earliest available start time for this machine
                start_time = max(machine_times[machine], task_tracker[job_id])
                
                # Update the machine's availability
                machine_times[machine] = start_time + duration
                
                # Add task to the repaired chromosome
                repaired_chromosome.append((job_id, (machine, duration)))
                task_tracker[job_id] += 1

    # Fill any missing tasks while maintaining order
    for job_id in range(len(jobs_data)):
        # Continue adding tasks for each job until all tasks are completed in the correct order
        while task_tracker[job_id] < len(jobs_data[job_id]):
            task = jobs_data[job_id][task_tracker[job_id]]
            repaired_chromosome.append((job_id, task))
            task_tracker[job_id] += 1

    return repaired_chromosome

# %%
def validate_and_repair_population(population, jobs_data):
    # ensures that  chromosome in the population is validated and repaired.
    return [repair_chromosome(chromosome, jobs_data) for chromosome in population]

# %%
def generate_population(jobs_data, population_size):
    population = []
    for i in range(population_size):
        chromosome = []
        for job_id, job in enumerate(jobs_data):
            for task in job:
                chromosome.append((job_id, task))
        if i < population_size // 2:
            random.shuffle(chromosome)
        # Repair the chromosome to ensure validity
        chromosome = repair_chromosome(chromosome, jobs_data)
        population.append(chromosome)
    return population

# %%
# Fitness function: Calculate makespan
def calculate_fitness(chromosome, machines_count, jobs_data):
    machine_times = [0] * machines_count
    job_times = [0] * len(jobs_data)

    for job_id, (machine, duration) in chromosome:
        start_time = max(machine_times[machine], job_times[job_id])
        end_time = start_time + duration
        machine_times[machine] = end_time
        job_times[job_id] = end_time

    return max(machine_times)

# %%
# Selection: Tournament selection
def tournament_selection(population, fitness, k=3):
    selected = random.sample(list(zip(population, fitness)), k)
    return min(selected, key=lambda x: x[1])[0]

# %%
#     Two-point crossover: Selects two points and swaps the segments between them.
def two_point_crossover(parent1, parent2, crossover_rate, jobs_data):
    if random.random() < crossover_rate:
        point1, point2 = sorted(random.sample(range(len(parent1)), 2))
        offspring1 = parent1[:point1] + parent2[point1:point2] + parent1[point2:]
        offspring2 = parent2[:point1] + parent1[point1:point2] + parent2[point2:]
        # Repair internally
        offspring1 = repair_chromosome(offspring1, jobs_data)
        offspring2 = repair_chromosome(offspring2, jobs_data)
    else:
        offspring1, offspring2 = parent1[:], parent2[:]

    return offspring1, offspring2

# %%
def uniform_crossover(parent1, parent2, crossover_rate, jobs_data):
    if random.random() < crossover_rate:
        offspring1, offspring2 = [], []
        for gene1, gene2 in zip(parent1, parent2):
            if random.random() < 0.5:
                offspring1.append(gene1)
                offspring2.append(gene2)
            else:
                offspring1.append(gene2)
                offspring2.append(gene1)
        
        # Repair offspring to maintain task order
        offspring1 = repair_chromosome(offspring1, jobs_data)
        offspring2 = repair_chromosome(offspring2, jobs_data)
    else:
        offspring1, offspring2 = parent1[:], parent2[:]

    return offspring1, offspring2

# %%
# Mutation: Always One Mutation per Chromosome ,To prevent getting stuck with bad solutions.
def always_one_mutation(chromosome, jobs_data):
    index1 = random.randint(0, len(chromosome) - 1)
    index2 = random.randint(0, len(chromosome) - 1)

    # Ensure that the two tasks belong to different jobs
    if chromosome[index1][0] != chromosome[index2][0]:
        chromosome[index1], chromosome[index2] = chromosome[index2], chromosome[index1]

    # Repair internally to maintain task order
    return repair_chromosome(chromosome, jobs_data)

# %%
# Mutation: Each Gene Mutates Independently
def independent_gene_mutation(chromosome, mutation_rate, jobs_data):
    for i in range(len(chromosome)):
        if random.random() < mutation_rate:
            swap_index = random.randint(0, len(chromosome) - 1)
            
            # Ensure that the two tasks belong to different jobs
            if chromosome[i][0] != chromosome[swap_index][0]:
                chromosome[i], chromosome[swap_index] = chromosome[swap_index], chromosome[i]

    # Repair internally to maintain task order
    return repair_chromosome(chromosome, jobs_data)

# %%
def genetic_algorithm(jobs_data, population_size=50, generations=100, crossover_rate=0.8, mutation_rate=0.1, elite_count=2):
    machines_count = len(set(machine for job in jobs_data for machine, _ in job))
    population = generate_population(jobs_data, population_size)
    population = validate_and_repair_population(population, jobs_data)
    best_solution = None
    best_fitness = float('inf')
    fitness_history = []

    for generation in range(generations):
        # Step 1: Calculate fitness
        fitness = [calculate_fitness(chromosome, machines_count, jobs_data) for chromosome in population]
        sorted_population = [x for _, x in sorted(zip(fitness, population), key=lambda pair: pair[0])]
        sorted_fitness = sorted(fitness)

        # Step 2: Select elites
        elites = sorted_population[:elite_count]
        new_population = elites[:]

        # Step 3: Generate new offspring
        while len(new_population) < population_size:
            parent1 = tournament_selection(population, fitness)
            parent2 = tournament_selection(population, fitness)

            # Step 4: Crossover
            if random.random() < crossover_rate:
                if random.random() < 0.5:
                    child1, child2 = two_point_crossover(parent1, parent2, crossover_rate, jobs_data)
                else:
                    child1, child2 = uniform_crossover(parent1, parent2, crossover_rate, jobs_data)
            else:
                child1, child2 = parent1, parent2

            # Mutation and repair are done internally in the mutation functions
            if random.random() < mutation_rate:
                child1 = always_one_mutation(child1, jobs_data)
                child2 = always_one_mutation(child2, jobs_data)

            new_population.append(child1)
            if len(new_population) < population_size:
                new_population.append(child2)

        # Step 8: Replace old population with new one
        population = new_population

        # Step 9: Track best solution
        best_gen_fitness = sorted_fitness[0]
        best_gen_solution = sorted_population[0]

        if best_gen_fitness < best_fitness:
            best_fitness = best_gen_fitness
            best_solution = best_gen_solution

        fitness_history.append(best_fitness)

    # Debugging statements to check types before return
    print(f"Returning types - Best Solution: {type(best_solution)}, Best Fitness: {type(best_fitness)}, Fitness History: {type(fitness_history)}")

    return best_solution, best_fitness, fitness_history

# %%
def simulated_annealing(jobs_data, initial_solution, initial_temperature, cooling_rate, max_iterations):
    # Calculate the total number of machines in the problem
    machines_count = len(set(machine for job in jobs_data for machine, _ in job))

    def neighbor_solution(current_solution, jobs_data):
        # Find tasks that can be swapped without breaking job order dependencies
        valid_swaps = []
        for i in range(len(current_solution)):
            for j in range(i + 1, len(current_solution)):
                job_i, task_i = current_solution[i]
                job_j, task_j = current_solution[j]
                if job_i != job_j:  # Allow swaps between different jobs only
                    valid_swaps.append((i, j))

        # Randomly select one of the valid swaps
        if valid_swaps:
            i, j = random.choice(valid_swaps)
            current_solution[i], current_solution[j] = current_solution[j], current_solution[i]

        return current_solution

    def repair_neighbor_solution(neighbor, jobs_data, machines_count):
        task_tracker = {job_id: 0 for job_id in range(len(jobs_data))}  # Track the next task for each job
        machine_availability = [0] * machines_count  # Track the availability time of each machine
        repaired_solution = []  # Store the repaired chromosome

        # Traverse the given neighbor and repair invalid sequences
        for job_id, (machine, duration) in neighbor:
            if task_tracker[job_id] < len(jobs_data[job_id]):
                expected_task = jobs_data[job_id][task_tracker[job_id]]

                # Ensure tasks follow the correct order for each job
                if (machine, duration) == expected_task:
                    repaired_solution.append((job_id, (machine, duration)))
                    task_tracker[job_id] += 1  # Update task tracker

        # Fill in any missing tasks in the correct order
        for job_id in range(len(jobs_data)):
            while task_tracker[job_id] < len(jobs_data[job_id]):
                machine, duration = jobs_data[job_id][task_tracker[job_id]]
                repaired_solution.append((job_id, (machine, duration)))
                task_tracker[job_id] += 1

        return repaired_solution

    current_solution = initial_solution  # Start with the initial solution
    current_fitness = calculate_fitness(current_solution, machines_count, jobs_data)  # Calculate initial fitness
    best_solution = current_solution  # Track the best solution
    best_fitness = current_fitness
    temperature = initial_temperature  # Initialize temperature

    fitness_history = [current_fitness]  # Track fitness improvement over iterations

    for iteration in range(max_iterations):
        # Generate a neighboring solution
        new_solution = neighbor_solution(current_solution, jobs_data)

        # Repair the neighbor solution to ensure it’s valid
        new_solution = repair_neighbor_solution(new_solution, jobs_data, machines_count)

        # Evaluate the fitness of the repaired neighbor
        new_fitness = calculate_fitness(new_solution, machines_count, jobs_data)

        # Decide whether to accept the new solution based on acceptance probability
        if new_fitness < current_fitness or random.random() < math.exp(-(new_fitness - current_fitness) / temperature):
            current_solution = new_solution
            current_fitness = new_fitness

            # Update the best solution if the new solution is better
            if new_fitness < best_fitness:
                best_solution = new_solution
                best_fitness = new_fitness

        # Reduce the temperature gradually to simulate the cooling process
        temperature *= cooling_rate
        fitness_history.append(best_fitness)  # Log the best fitness at each iteration

        # Stop if the temperature becomes very small
        if temperature < 1e-6:
            break

    # Return the best solution found, its fitness, and the fitness evolution over iterations
    return best_solution, best_fitness, fitness_history

# %%
# Main code
file_path = 'jobshop1.txt'
instance_name = 'abz5'

try:
    # Parse dataset
    jobs_data, machines_count = parse_dataset(file_path, instance_name)
    print(f"Parsed Jobs Data: {jobs_data}")
    print(f"Machines Count: {machines_count}")

    # Define GA parameter combinations
    ga_parameter_combinations = [
        {"population_size": 300, "mutation_rate": 0.1, "crossover_rate": 0.8, "elitism": 2},
        {"population_size": 250, "mutation_rate": 0.05, "crossover_rate": 0.7, "elitism": 2},
        {"population_size": 50, "mutation_rate": 0.2, "crossover_rate": 0.5, "elitism": 1},
        {"population_size": 200, "mutation_rate": 0.2, "crossover_rate": 0.9, "elitism": 3},
        {"population_size": 100, "mutation_rate": 0.1, "crossover_rate": 0.6, "elitism": 1},
        {"population_size": 400, "mutation_rate": 0.05, "crossover_rate": 0.9, "elitism": 3},
    ]

    # Store GA results
    ga_results = []

    # Run Genetic Algorithm for each parameter combination
    for params in ga_parameter_combinations:
        print(f"\nRunning GA with parameters: {params}")
        ga_best_solution, ga_best_fitness, ga_fitness_history = genetic_algorithm(
            jobs_data, params["population_size"], 100, params["crossover_rate"],
            params["mutation_rate"], params["elitism"]
        )

        # Save results
        ga_results.append({
            "parameters": params,
            "best_fitness": ga_best_fitness,
            "best_solution": ga_best_solution,
            "fitness_history": ga_fitness_history,
        })

        # Print results for GA
        print(f"GA Results - Parameters: {params}")
        print(f"Best Fitness (Makespan): {ga_best_fitness}")
        print(f"Best Solution: {ga_best_solution}")

        # Plot fitness evolution
        plt.figure()
        plt.plot(ga_fitness_history, label=f"GA - Pop: {params['population_size']}, Mut: {params['mutation_rate']}, X: {params['crossover_rate']}, E: {params['elitism']}")
        plt.xlabel('Generation')
        plt.ylabel('Best Fitness (Makespan)')
        plt.title(f"Fitness Evolution (GA - Pop: {params['population_size']}, Mut: {params['mutation_rate']}, X: {params['crossover_rate']}, E: {params['elitism']})")
        plt.legend()
        plt.savefig(f"fitness_evolution_ga_pop{params['population_size']}_mut{params['mutation_rate']}_xover{params['crossover_rate']}_elitism{params['elitism']}.png")
        plt.close()

    # Define SA parameter combinations
    sa_parameter_combinations = [
        {"initial_temperature": 1000, "cooling_rate": 0.99, "max_iterations": 1000},
        {"initial_temperature": 500, "cooling_rate": 0.95, "max_iterations": 1000},
        {"initial_temperature": 1500, "cooling_rate": 0.98, "max_iterations": 1500},
        {"initial_temperature": 800, "cooling_rate": 0.97, "max_iterations": 1200},
        {"initial_temperature": 1200, "cooling_rate": 0.96, "max_iterations": 1500},
        {"initial_temperature": 700, "cooling_rate": 0.94, "max_iterations": 1100},
    ]

    # Store SA results
    sa_results = []

    # Run Simulated Annealing for each parameter combination
    for params in sa_parameter_combinations:
        print(f"\nRunning SA with parameters: {params}")
    #one solution , first only solution
        sa_initial_solution = generate_population(jobs_data, 1)[0]
        sa_best_solution, sa_best_fitness, sa_fitness_history = simulated_annealing(
            jobs_data, sa_initial_solution, params["initial_temperature"], params["cooling_rate"], params["max_iterations"]
        )

        # Save results
        sa_results.append({
            "parameters": params,
            "best_fitness": sa_best_fitness,
            "best_solution": sa_best_solution,
            "fitness_history": sa_fitness_history,
        })

        # Print results for SA
        print(f"SA Results - Parameters: {params}")
        print(f"Best Fitness (Makespan): {sa_best_fitness}")
        print(f"Best Solution: {sa_best_solution}")

        # Plot fitness evolution
        plt.figure()
        plt.plot(sa_fitness_history, label=f"SA - Temp: {params['initial_temperature']}, Cool: {params['cooling_rate']}, Iter: {params['max_iterations']}")
        plt.xlabel('Iteration')
        plt.ylabel('Best Fitness (Makespan)')
        plt.title(f"Fitness Evolution (SA - Temp: {params['initial_temperature']}, Cool: {params['cooling_rate']}, Iter: {params['max_iterations']})")
        plt.legend()
        plt.savefig(f"fitness_evolution_sa_temp{params['initial_temperature']}_cool{params['cooling_rate']}_iter{params['max_iterations']}.png")
        plt.close()

except Exception as e:
    print(f"Error: {e}")
# Out:
# Parsed Jobs Data: [[(4, 88), (8, 68), (6, 94), (5, 99), (1, 67), (2, 89), (9, 77), (7, 99), (0, 86), (3, 92)], [(5, 72), (3, 50), (6, 69), (4, 75), (2, 94), (8, 66), (0, 92), (1, 82), (7, 94), (9, 63)], [(9, 83), (8, 61), (0, 83), (1, 65), (6, 64), (5, 85), (7, 78), (4, 85), (2, 55), (3, 77)], [(7, 94), (2, 68), (1, 61), (4, 99), (3, 54), (6, 75), (5, 66), (0, 76), (9, 63), (8, 67)], [(3, 69), (4, 88), (9, 82), (8, 95), (0, 99), (2, 67), (6, 95), (5, 68), (7, 67), (1, 86)], [(1, 99), (4, 81), (5, 64), (6, 66), (8, 80), (2, 80), (7, 69), (9, 62), (3, 79), (0, 88)], [(7, 50), (1, 86), (4, 97), (3, 96), (0, 95), (8, 97), (2, 66), (5, 99), (6, 52), (9, 71)], [(4, 98), (6, 73), (3, 82), (2, 51), (1, 71), (5, 94), (7, 85), (0, 62), (8, 95), (9, 79)], [(0, 94), (6, 71), (3, 81), (7, 85), (1, 66), (2, 90), (4, 76), (5, 58), (8, 93), (9, 97)], [(3, 50), (0, 59), (1, 82), (8, 67), (7, 56), (9, 96), (6, 58), (4, 81), (5, 59), (2, 96)]]
# Machines Count: 10
#
# Running GA with parameters: {'population_size': 300, 'mutation_rate': 0.1, 'crossover_rate': 0.8, 'elitism': 2}
# Returning types - Best Solution: <class 'list'>, Best Fitness: <class 'int'>, Fitness History: <class 'list'>
# GA Results - Parameters: {'population_size': 300, 'mutation_rate': 0.1, 'crossover_rate': 0.8, 'elitism': 2}
# Best Fitness (Makespan): 1641
# Best Solution: [(0, (4, 88)), (8, (0, 94)), (9, (8, 67)), (6, (2, 66)), (5, (4, 81)), (2, (9, 83)), (7, (6, 73)), (1, (5, 72)), (3, (7, 94)), (6, (8, 97)), (6, (7, 50)), (0, (6, 94)), (4, (3, 69)), (8, (6, 71)), (9, (3, 50)), (6, (1, 86)), (9, (6, 58)), (0, (5, 99)), (0, (1, 67)), (4, (4, 88)), (4, (9, 82)), (7, (3, 82)), (7, (2, 51)), (1, (8, 66)), (7, (5, 94)), (8, (3, 81)), (0, (2, 89)), (0, (9, 77)), (0, (7, 99)), (0, (0, 86)), (0, (3, 92)), (1, (6, 69)), (1, (4, 75)), (6, (5, 99)), (7, (1, 71)), (1, (2, 94)), (5, (6, 66)), (5, (8, 80)), (5, (2, 80)), (5, (7, 69)), (5, (9, 62)), (5, (3, 79)), (4, (8, 95)), (6, (4, 97)), (3, (2, 68)), (3, (1, 61)), (3, (4, 99)), (6, (9, 71)), (7, (8, 95)), (8, (7, 85)), (8, (1, 66)), (8, (2, 90)), (8, (4, 76)), (8, (5, 58)), (2, (1, 65)), (9, (0, 59)), (1, (0, 92)), (1, (1, 82)), (1, (7, 94)), (4, (0, 99)), (2, (8, 61)), (2, (0, 83)), (3, (5, 66)), (8, (8, 93)), (9, (1, 82)), (6, (3, 96)), (2, (6, 64)), (2, (5, 85)), (5, (1, 99)), (9, (7, 56)), (3, (0, 76)), (3, (9, 63)), (3, (8, 67)), (4, (2, 67)), (9, (9, 96)), (5, (0, 88)), (4, (6, 95)), (6, (0, 95)), (0, (8, 68)), (7, (4, 98)), (4, (5, 68)), (8, (9, 97)), (1, (9, 63)), (2, (7, 78)), (2, (4, 85)), (2, (2, 55)), (2, (3, 77)), (1, (3, 50)), (9, (4, 81)), (9, (5, 59)), (9, (2, 96)), (5, (5, 64)), (6, (6, 52)), (7, (7, 85)), (7, (0, 62)), (3, (6, 75)), (7, (9, 79)), (4, (7, 67)), (4, (1, 86)), (3, (3, 54))]
#
# Running GA with parameters: {'population_size': 250, 'mutation_rate': 0.05, 'crossover_rate': 0.7, 'elitism': 2}
# Returning types - Best Solution: <class 'list'>, Best Fitness: <class 'int'>, Fitness History: <class 'list'>
# GA Results - Parameters: {'population_size': 250, 'mutation_rate': 0.05, 'crossover_rate': 0.7, 'elitism': 2}
# Best Fitness (Makespan): 1694
# Best Solution: [(3, (7, 94)), (9, (3, 50)), (2, (9, 83)), (3, (2, 68)), (8, (0, 94)), (0, (4, 88)), (7, (4, 98)), (3, (1, 61)), (7, (6, 73)), (9, (0, 59)), (4, (3, 69)), (1, (5, 72)), (2, (8, 61)), (7, (3, 82)), (3, (4, 99)), (9, (1, 82)), (7, (2, 51)), (1, (3, 50)), (0, (8, 68)), (5, (1, 99)), (6, (7, 50)), (0, (6, 94)), (8, (7, 85)), (3, (6, 75)), (0, (1, 67)), (4, (4, 88)), (4, (9, 82)), (4, (8, 95)), (4, (0, 99)), (4, (2, 67)), (8, (9, 97)), (5, (5, 64)), (6, (1, 86)), (6, (4, 97)), (6, (3, 96)), (7, (1, 71)), (7, (5, 94)), (7, (7, 85)), (1, (1, 82)), (8, (6, 71)), (8, (3, 81)), (3, (3, 54)), (8, (1, 66)), (8, (2, 90)), (8, (4, 76)), (5, (6, 66)), (9, (8, 67)), (9, (7, 56)), (9, (9, 96)), (6, (0, 95)), (2, (0, 83)), (5, (8, 80)), (3, (9, 63)), (5, (2, 80)), (2, (1, 65)), (5, (7, 69)), (1, (6, 69)), (1, (4, 75)), (2, (6, 64)), (0, (5, 99)), (3, (5, 66)), (0, (2, 89)), (5, (9, 62)), (6, (8, 97)), (2, (5, 85)), (2, (7, 78)), (0, (9, 77)), (1, (2, 94)), (8, (5, 58)), (1, (8, 66)), (3, (8, 67)), (2, (4, 85)), (8, (8, 93)), (7, (0, 62)), (6, (2, 66)), (1, (0, 92)), (4, (6, 95)), (4, (5, 68)), (5, (3, 79)), (6, (5, 99)), (6, (6, 52)), (6, (9, 71)), (7, (8, 95)), (5, (4, 81)), (7, (9, 79)), (9, (6, 58)), (3, (0, 76)), (0, (7, 99)), (0, (0, 86)), (0, (3, 92)), (1, (7, 94)), (1, (9, 63)), (2, (2, 55)), (2, (3, 77)), (4, (7, 67)), (4, (1, 86)), (5, (0, 88)), (9, (4, 81)), (9, (5, 59)), (9, (2, 96))]
#
# Running GA with parameters: {'population_size': 50, 'mutation_rate': 0.2, 'crossover_rate': 0.5, 'elitism': 1}
# Returning types - Best Solution: <class 'list'>, Best Fitness: <class 'int'>, Fitness History: <class 'list'>
# GA Results - Parameters: {'population_size': 50, 'mutation_rate': 0.2, 'crossover_rate': 0.5, 'elitism': 1}
# Best Fitness (Makespan): 1466
# Best Solution: [(2, (3, 77)), (8, (0, 94)), (7, (8, 95)), (7, (4, 98)), (8, (2, 90)), (1, (5, 72)), (6, (7, 50)), (2, (9, 83)), (9, (3, 50)), (9, (4, 81)), (3, (7, 94)), (9, (7, 56)), (7, (3, 82)), (7, (9, 79)), (4, (3, 69)), (3, (5, 66)), (6, (6, 52)), (3, (0, 76)), (3, (6, 75)), (0, (5, 99)), (0, (1, 67)), (1, (0, 92)), (9, (8, 67)), (1, (2, 94)), (4, (4, 88)), (4, (9, 82)), (4, (8, 95)), (5, (1, 99)), (1, (4, 75)), (2, (7, 78)), (2, (0, 83)), (5, (4, 81)), (5, (5, 64)), (0, (9, 77)), (7, (1, 71)), (7, (5, 94)), (6, (0, 95)), (1, (3, 50)), (1, (6, 69)), (2, (4, 85)), (9, (0, 59)), (9, (1, 82)), (5, (6, 66)), (7, (2, 51)), (3, (1, 61)), (1, (8, 66)), (8, (4, 76)), (6, (3, 96)), (2, (1, 65)), (3, (2, 68)), (4, (5, 68)), (1, (1, 82)), (8, (8, 93)), (0, (0, 86)), (6, (4, 97)), (8, (3, 81)), (9, (9, 96)), (9, (6, 58)), (8, (5, 58)), (0, (8, 68)), (1, (9, 63)), (8, (9, 97)), (5, (0, 88)), (0, (4, 88)), (2, (8, 61)), (4, (2, 67)), (7, (7, 85)), (5, (2, 80)), (2, (5, 85)), (4, (0, 99)), (6, (8, 97)), (5, (3, 79)), (0, (6, 94)), (5, (7, 69)), (6, (1, 86)), (6, (5, 99)), (4, (7, 67)), (4, (6, 95)), (0, (2, 89)), (7, (6, 73)), (4, (1, 86)), (5, (8, 80)), (7, (0, 62)), (8, (7, 85)), (5, (9, 62)), (3, (3, 54)), (0, (7, 99)), (8, (1, 66)), (2, (2, 55)), (3, (4, 99)), (6, (2, 66)), (3, (9, 63)), (2, (6, 64)), (6, (9, 71)), (3, (8, 67)), (9, (5, 59)), (9, (2, 96)), (8, (6, 71)), (1, (7, 94)), (0, (3, 92))]
#
# Running GA with parameters: {'population_size': 200, 'mutation_rate': 0.2, 'crossover_rate': 0.9, 'elitism': 3}
# Returning types - Best Solution: <class 'list'>, Best Fitness: <class 'int'>, Fitness History: <class 'list'>
# GA Results - Parameters: {'population_size': 200, 'mutation_rate': 0.2, 'crossover_rate': 0.9, 'elitism': 3}
# Best Fitness (Makespan): 1780
# Best Solution: [(3, (7, 94)), (4, (3, 69)), (7, (4, 98)), (8, (0, 94)), (4, (4, 88)), (1, (5, 72)), (5, (1, 99)), (0, (4, 88)), (9, (3, 50)), (5, (4, 81)), (3, (3, 54)), (9, (0, 59)), (6, (7, 50)), (7, (6, 73)), (8, (6, 71)), (4, (9, 82)), (3, (2, 68)), (0, (8, 68)), (5, (5, 64)), (1, (3, 50)), (1, (6, 69)), (6, (0, 95)), (1, (2, 94)), (5, (6, 66)), (3, (1, 61)), (3, (4, 99)), (2, (9, 83)), (3, (6, 75)), (4, (8, 95)), (4, (0, 99)), (4, (2, 67)), (3, (5, 66)), (2, (8, 61)), (2, (0, 83)), (7, (3, 82)), (4, (6, 95)), (3, (0, 76)), (3, (9, 63)), (3, (8, 67)), (6, (1, 86)), (6, (4, 97)), (6, (3, 96)), (1, (4, 75)), (9, (1, 82)), (7, (2, 51)), (7, (1, 71)), (7, (5, 94)), (8, (3, 81)), (6, (8, 97)), (8, (7, 85)), (1, (8, 66)), (1, (0, 92)), (6, (2, 66)), (2, (1, 65)), (2, (6, 64)), (2, (5, 85)), (2, (7, 78)), (2, (4, 85)), (7, (7, 85)), (9, (8, 67)), (0, (6, 94)), (0, (5, 99)), (0, (1, 67)), (0, (2, 89)), (0, (9, 77)), (2, (2, 55)), (9, (7, 56)), (5, (8, 80)), (7, (0, 62)), (8, (1, 66)), (1, (1, 82)), (0, (7, 99)), (0, (0, 86)), (9, (9, 96)), (6, (5, 99)), (6, (6, 52)), (6, (9, 71)), (1, (7, 94)), (8, (2, 90)), (7, (8, 95)), (0, (3, 92)), (1, (9, 63)), (5, (2, 80)), (5, (7, 69)), (5, (9, 62)), (5, (3, 79)), (8, (4, 76)), (7, (9, 79)), (4, (5, 68)), (8, (5, 58)), (9, (6, 58)), (9, (4, 81)), (8, (8, 93)), (8, (9, 97)), (9, (5, 59)), (9, (2, 96)), (2, (3, 77)), (4, (7, 67)), (4, (1, 86)), (5, (0, 88))]
#
# Running GA with parameters: {'population_size': 100, 'mutation_rate': 0.1, 'crossover_rate': 0.6, 'elitism': 1}
# Returning types - Best Solution: <class 'list'>, Best Fitness: <class 'int'>, Fitness History: <class 'list'>
# GA Results - Parameters: {'population_size': 100, 'mutation_rate': 0.1, 'crossover_rate': 0.6, 'elitism': 1}
# Best Fitness (Makespan): 1783
# Best Solution: [(9, (1, 82)), (1, (2, 94)), (9, (2, 96)), (7, (4, 98)), (3, (7, 94)), (6, (1, 86)), (8, (0, 94)), (5, (6, 66)), (6, (4, 97)), (9, (3, 50)), (3, (3, 54)), (4, (4, 88)), (7, (6, 73)), (8, (6, 71)), (2, (0, 83)), (2, (1, 65)), (1, (5, 72)), (3, (2, 68)), (5, (1, 99)), (5, (3, 79)), (0, (8, 68)), (0, (6, 94)), (6, (0, 95)), (2, (8, 61)), (0, (2, 89)), (0, (9, 77)), (0, (7, 99)), (3, (1, 61)), (4, (9, 82)), (6, (2, 66)), (4, (0, 99)), (5, (4, 81)), (5, (5, 64)), (0, (4, 88)), (5, (8, 80)), (1, (9, 63)), (3, (6, 75)), (3, (5, 66)), (1, (0, 92)), (6, (3, 96)), (1, (4, 75)), (7, (3, 82)), (1, (8, 66)), (7, (1, 71)), (3, (4, 99)), (7, (7, 85)), (6, (5, 99)), (7, (8, 95)), (7, (9, 79)), (8, (3, 81)), (8, (7, 85)), (8, (1, 66)), (0, (3, 92)), (4, (3, 69)), (9, (8, 67)), (9, (7, 56)), (4, (5, 68)), (2, (6, 64)), (2, (5, 85)), (8, (4, 76)), (0, (0, 86)), (8, (2, 90)), (4, (6, 95)), (1, (6, 69)), (9, (5, 59)), (6, (7, 50)), (7, (2, 51)), (3, (0, 76)), (1, (1, 82)), (1, (7, 94)), (0, (1, 67)), (9, (6, 58)), (9, (4, 81)), (0, (5, 99)), (4, (7, 67)), (3, (9, 63)), (3, (8, 67)), (4, (2, 67)), (5, (9, 62)), (9, (9, 96)), (2, (9, 83)), (4, (1, 86)), (7, (5, 94)), (5, (2, 80)), (5, (7, 69)), (2, (2, 55)), (9, (0, 59)), (5, (0, 88)), (6, (8, 97)), (4, (8, 95)), (7, (0, 62)), (6, (6, 52)), (6, (9, 71)), (2, (7, 78)), (2, (4, 85)), (1, (3, 50)), (2, (3, 77)), (8, (5, 58)), (8, (8, 93)), (8, (9, 97))]
#
# Running GA with parameters: {'population_size': 400, 'mutation_rate': 0.05, 'crossover_rate': 0.9, 'elitism': 3}
# Returning types - Best Solution: <class 'list'>, Best Fitness: <class 'int'>, Fitness History: <class 'list'>
# GA Results - Parameters: {'population_size': 400, 'mutation_rate': 0.05, 'crossover_rate': 0.9, 'elitism': 3}
# Best Fitness (Makespan): 1788
# Best Solution: [(6, (7, 50)), (2, (9, 83)), (3, (7, 94)), (8, (0, 94)), (3, (2, 68)), (8, (6, 71)), (2, (8, 61)), (1, (5, 72)), (2, (0, 83)), (7, (4, 98)), (5, (1, 99)), (0, (4, 88)), (0, (8, 68)), (3, (1, 61)), (1, (3, 50)), (3, (4, 99)), (4, (3, 69)), (1, (6, 69)), (3, (3, 54)), (2, (1, 65)), (9, (3, 50)), (6, (1, 86)), (0, (6, 94)), (0, (5, 99)), (0, (1, 67)), (0, (2, 89)), (0, (9, 77)), (0, (7, 99)), (3, (6, 75)), (9, (0, 59)), (7, (6, 73)), (6, (4, 97)), (8, (3, 81)), (3, (5, 66)), (9, (1, 82)), (1, (4, 75)), (1, (2, 94)), (7, (3, 82)), (3, (0, 76)), (9, (8, 67)), (9, (7, 56)), (9, (9, 96)), (4, (4, 88)), (8, (7, 85)), (1, (8, 66)), (1, (0, 92)), (1, (1, 82)), (2, (6, 64)), (5, (4, 81)), (5, (5, 64)), (5, (6, 66)), (5, (8, 80)), (5, (2, 80)), (2, (5, 85)), (9, (6, 58)), (9, (4, 81)), (9, (5, 59)), (2, (7, 78)), (4, (9, 82)), (4, (8, 95)), (4, (0, 99)), (6, (3, 96)), (6, (0, 95)), (6, (8, 97)), (5, (7, 69)), (5, (9, 62)), (5, (3, 79)), (7, (2, 51)), (7, (1, 71)), (7, (5, 94)), (7, (7, 85)), (3, (9, 63)), (1, (7, 94)), (4, (2, 67)), (7, (0, 62)), (8, (1, 66)), (4, (6, 95)), (1, (9, 63)), (7, (8, 95)), (7, (9, 79)), (8, (2, 90)), (8, (4, 76)), (8, (5, 58)), (8, (8, 93)), (8, (9, 97)), (0, (0, 86)), (6, (2, 66)), (3, (8, 67)), (4, (5, 68)), (5, (0, 88)), (2, (4, 85)), (6, (5, 99)), (9, (2, 96)), (2, (2, 55)), (0, (3, 92)), (2, (3, 77)), (6, (6, 52)), (6, (9, 71)), (4, (7, 67)), (4, (1, 86))]
#
# Running SA with parameters: {'initial_temperature': 1000, 'cooling_rate': 0.99, 'max_iterations': 1000}
# SA Results - Parameters: {'initial_temperature': 1000, 'cooling_rate': 0.99, 'max_iterations': 1000}
# Best Fitness (Makespan): 3054
# Best Solution: [(2, (9, 83)), (0, (4, 88)), (0, (8, 68)), (2, (8, 61)), (5, (1, 99)), (9, (3, 50)), (7, (4, 98)), (0, (6, 94)), (0, (5, 99)), (7, (6, 73)), (3, (7, 94)), (4, (9, 82)), (7, (3, 82)), (2, (0, 83)), (2, (1, 65)), (2, (6, 64)), (2, (5, 85)), (3, (1, 61)), (3, (4, 99)), (3, (3, 54)), (9, (0, 59)), (7, (2, 51)), (3, (6, 75)), (5, (4, 81)), (5, (5, 64)), (5, (6, 66)), (5, (8, 80)), (5, (2, 80)), (1, (5, 72)), (8, (0, 94)), (9, (1, 82)), (9, (8, 67)), (9, (7, 56)), (9, (9, 96)), (9, (6, 58)), (9, (4, 81)), (4, (3, 69)), (5, (7, 69)), (2, (7, 78)), (5, (9, 62)), (1, (3, 50)), (1, (6, 69)), (7, (1, 71)), (2, (4, 85)), (2, (2, 55)), (1, (4, 75)), (8, (6, 71)), (6, (7, 50)), (5, (3, 79)), (8, (3, 81)), (8, (7, 85)), (8, (1, 66)), (8, (2, 90)), (3, (5, 66)), (3, (0, 76)), (3, (9, 63)), (3, (8, 67)), (7, (5, 94)), (7, (7, 85)), (7, (0, 62)), (7, (8, 95)), (7, (9, 79)), (1, (2, 94)), (2, (3, 77)), (4, (4, 88)), (3, (2, 68)), (4, (8, 95)), (4, (0, 99)), (4, (2, 67)), (4, (6, 95)), (4, (5, 68)), (6, (1, 86)), (9, (5, 59)), (1, (8, 66)), (5, (0, 88)), (6, (4, 97)), (6, (3, 96)), (0, (1, 67)), (0, (2, 89)), (0, (9, 77)), (0, (7, 99)), (0, (0, 86)), (0, (3, 92)), (4, (7, 67)), (4, (1, 86)), (6, (0, 95)), (6, (8, 97)), (6, (2, 66)), (6, (5, 99)), (6, (6, 52)), (6, (9, 71)), (1, (0, 92)), (1, (1, 82)), (1, (7, 94)), (1, (9, 63)), (9, (2, 96)), (8, (4, 76)), (8, (5, 58)), (8, (8, 93)), (8, (9, 97))]
#
# Running SA with parameters: {'initial_temperature': 500, 'cooling_rate': 0.95, 'max_iterations': 1000}
# SA Results - Parameters: {'initial_temperature': 500, 'cooling_rate': 0.95, 'max_iterations': 1000}
# Best Fitness (Makespan): 3635
# Best Solution: [(0, (4, 88)), (3, (1, 61)), (8, (9, 97)), (2, (1, 65)), (1, (4, 75)), (1, (2, 94)), (1, (8, 66)), (1, (0, 92)), (1, (6, 69)), (3, (7, 94)), (3, (2, 68)), (4, (3, 69)), (4, (4, 88)), (9, (0, 59)), (0, (8, 68)), (6, (8, 97)), (5, (4, 81)), (5, (5, 64)), (6, (1, 86)), (7, (4, 98)), (7, (6, 73)), (5, (6, 66)), (8, (0, 94)), (8, (6, 71)), (8, (3, 81)), (8, (7, 85)), (8, (1, 66)), (2, (9, 83)), (1, (7, 94)), (4, (9, 82)), (9, (1, 82)), (4, (8, 95)), (1, (1, 82)), (0, (6, 94)), (0, (5, 99)), (0, (1, 67)), (5, (7, 69)), (0, (9, 77)), (0, (7, 99)), (0, (0, 86)), (5, (8, 80)), (9, (8, 67)), (4, (0, 99)), (9, (7, 56)), (2, (8, 61)), (2, (0, 83)), (6, (7, 50)), (2, (6, 64)), (2, (5, 85)), (1, (5, 72)), (7, (3, 82)), (8, (2, 90)), (9, (9, 96)), (9, (6, 58)), (9, (4, 81)), (9, (5, 59)), (2, (7, 78)), (2, (4, 85)), (2, (2, 55)), (2, (3, 77)), (3, (4, 99)), (7, (2, 51)), (7, (1, 71)), (7, (5, 94)), (7, (7, 85)), (7, (0, 62)), (7, (8, 95)), (7, (9, 79)), (4, (2, 67)), (8, (4, 76)), (0, (3, 92)), (4, (6, 95)), (4, (5, 68)), (4, (7, 67)), (6, (5, 99)), (5, (2, 80)), (0, (2, 89)), (5, (9, 62)), (5, (3, 79)), (5, (0, 88)), (8, (5, 58)), (8, (8, 93)), (1, (3, 50)), (3, (3, 54)), (3, (6, 75)), (3, (5, 66)), (3, (0, 76)), (3, (9, 63)), (3, (8, 67)), (9, (2, 96)), (9, (3, 50)), (1, (9, 63)), (6, (4, 97)), (6, (3, 96)), (6, (0, 95)), (5, (1, 99)), (6, (2, 66)), (4, (1, 86)), (6, (6, 52)), (6, (9, 71))]
#
# Running SA with parameters: {'initial_temperature': 1500, 'cooling_rate': 0.98, 'max_iterations': 1500}
# SA Results - Parameters: {'initial_temperature': 1500, 'cooling_rate': 0.98, 'max_iterations': 1500}
# Best Fitness (Makespan): 3345
# Best Solution: [(1, (5, 72)), (2, (9, 83)), (8, (0, 94)), (8, (6, 71)), (3, (7, 94)), (8, (3, 81)), (9, (3, 50)), (2, (8, 61)), (2, (0, 83)), (2, (1, 65)), (9, (0, 59)), (4, (3, 69)), (8, (7, 85)), (0, (4, 88)), (7, (4, 98)), (7, (6, 73)), (6, (7, 50)), (1, (3, 50)), (0, (8, 68)), (0, (6, 94)), (1, (6, 69)), (0, (5, 99)), (0, (1, 67)), (9, (1, 82)), (6, (1, 86)), (6, (4, 97)), (6, (3, 96)), (6, (0, 95)), (6, (8, 97)), (9, (8, 67)), (7, (3, 82)), (5, (1, 99)), (4, (4, 88)), (1, (4, 75)), (1, (2, 94)), (1, (8, 66)), (1, (0, 92)), (8, (1, 66)), (0, (2, 89)), (0, (9, 77)), (0, (7, 99)), (0, (0, 86)), (0, (3, 92)), (1, (1, 82)), (1, (7, 94)), (4, (9, 82)), (4, (8, 95)), (4, (0, 99)), (4, (2, 67)), (4, (6, 95)), (4, (5, 68)), (3, (2, 68)), (5, (4, 81)), (5, (5, 64)), (5, (6, 66)), (2, (6, 64)), (8, (2, 90)), (8, (4, 76)), (7, (2, 51)), (6, (2, 66)), (9, (7, 56)), (9, (9, 96)), (1, (9, 63)), (3, (1, 61)), (3, (4, 99)), (3, (3, 54)), (3, (6, 75)), (3, (5, 66)), (3, (0, 76)), (3, (9, 63)), (3, (8, 67)), (9, (2, 96)), (4, (1, 86)), (9, (6, 58)), (9, (4, 81)), (9, (5, 59)), (4, (7, 67)), (6, (5, 99)), (6, (6, 52)), (6, (9, 71)), (2, (5, 85)), (2, (7, 78)), (2, (4, 85)), (2, (2, 55)), (2, (3, 77)), (5, (8, 80)), (5, (2, 80)), (5, (7, 69)), (5, (9, 62)), (5, (3, 79)), (5, (0, 88)), (7, (1, 71)), (7, (5, 94)), (7, (7, 85)), (7, (0, 62)), (7, (8, 95)), (7, (9, 79)), (8, (5, 58)), (8, (8, 93)), (8, (9, 97))]
#
# Running SA with parameters: {'initial_temperature': 800, 'cooling_rate': 0.97, 'max_iterations': 1200}
# SA Results - Parameters: {'initial_temperature': 800, 'cooling_rate': 0.97, 'max_iterations': 1200}
# Best Fitness (Makespan): 3231
# Best Solution: [(4, (8, 95)), (2, (7, 78)), (3, (9, 63)), (8, (7, 85)), (0, (2, 89)), (0, (0, 86)), (1, (7, 94)), (5, (3, 79)), (7, (9, 79)), (0, (4, 88)), (4, (9, 82)), (2, (6, 64)), (4, (5, 68)), (2, (8, 61)), (7, (1, 71)), (7, (8, 95)), (6, (3, 96)), (1, (0, 92)), (3, (2, 68)), (7, (3, 82)), (0, (3, 92)), (8, (4, 76)), (9, (7, 56)), (6, (7, 50)), (5, (7, 69)), (2, (1, 65)), (8, (6, 71)), (7, (4, 98)), (5, (6, 66)), (1, (8, 66)), (4, (2, 67)), (1, (3, 50)), (4, (0, 99)), (9, (3, 50)), (4, (4, 88)), (1, (1, 82)), (3, (0, 76)), (9, (1, 82)), (0, (5, 99)), (9, (4, 81)), (1, (4, 75)), (2, (4, 85)), (7, (6, 73)), (2, (5, 85)), (3, (8, 67)), (6, (1, 86)), (6, (4, 97)), (7, (0, 62)), (5, (1, 99)), (0, (8, 68)), (8, (2, 90)), (9, (0, 59)), (0, (9, 77)), (2, (2, 55)), (5, (5, 64)), (6, (2, 66)), (8, (8, 93)), (6, (8, 97)), (5, (9, 62)), (1, (6, 69)), (9, (5, 59)), (8, (3, 81)), (1, (9, 63)), (3, (6, 75)), (3, (4, 99)), (9, (9, 96)), (2, (9, 83)), (3, (3, 54)), (7, (2, 51)), (9, (6, 58)), (2, (3, 77)), (3, (5, 66)), (1, (5, 72)), (1, (2, 94)), (4, (6, 95)), (7, (5, 94)), (5, (2, 80)), (7, (7, 85)), (2, (0, 83)), (0, (7, 99)), (6, (6, 52)), (4, (7, 67)), (8, (9, 97)), (8, (5, 58)), (4, (1, 86)), (9, (2, 96)), (8, (0, 94)), (6, (5, 99)), (5, (0, 88)), (6, (9, 71)), (0, (6, 94)), (4, (3, 69)), (5, (4, 81)), (3, (7, 94)), (0, (1, 67)), (5, (8, 80)), (9, (8, 67)), (8, (1, 66)), (3, (1, 61)), (6, (0, 95))]
#
# Running SA with parameters: {'initial_temperature': 1200, 'cooling_rate': 0.96, 'max_iterations': 1500}
# SA Results - Parameters: {'initial_temperature': 1200, 'cooling_rate': 0.96, 'max_iterations': 1500}
# Best Fitness (Makespan): 3380
# Best Solution: [(0, (4, 88)), (0, (8, 68)), (1, (5, 72)), (1, (3, 50)), (1, (6, 69)), (1, (4, 75)), (1, (2, 94)), (2, (9, 83)), (2, (8, 61)), (3, (7, 94)), (4, (3, 69)), (5, (1, 99)), (4, (4, 88)), (5, (4, 81)), (5, (5, 64)), (5, (6, 66)), (5, (8, 80)), (5, (2, 80)), (6, (7, 50)), (6, (1, 86)), (6, (4, 97)), (6, (3, 96)), (6, (0, 95)), (6, (8, 97)), (6, (2, 66)), (7, (4, 98)), (2, (0, 83)), (9, (3, 50)), (9, (0, 59)), (9, (1, 82)), (9, (8, 67)), (8, (0, 94)), (9, (7, 56)), (9, (9, 96)), (3, (2, 68)), (1, (8, 66)), (5, (7, 69)), (3, (1, 61)), (0, (6, 94)), (7, (6, 73)), (2, (1, 65)), (2, (6, 64)), (2, (5, 85)), (9, (6, 58)), (6, (5, 99)), (4, (9, 82)), (9, (4, 81)), (1, (1, 82)), (1, (7, 94)), (1, (9, 63)), (4, (8, 95)), (4, (0, 99)), (4, (2, 67)), (4, (6, 95)), (5, (9, 62)), (7, (3, 82)), (7, (2, 51)), (7, (1, 71)), (7, (5, 94)), (7, (7, 85)), (7, (0, 62)), (7, (8, 95)), (7, (9, 79)), (4, (5, 68)), (4, (7, 67)), (4, (1, 86)), (5, (3, 79)), (5, (0, 88)), (6, (6, 52)), (6, (9, 71)), (8, (6, 71)), (8, (3, 81)), (8, (7, 85)), (8, (1, 66)), (8, (2, 90)), (8, (4, 76)), (8, (5, 58)), (8, (8, 93)), (8, (9, 97)), (0, (5, 99)), (0, (1, 67)), (0, (2, 89)), (0, (9, 77)), (0, (7, 99)), (0, (0, 86)), (0, (3, 92)), (2, (7, 78)), (2, (4, 85)), (2, (2, 55)), (2, (3, 77)), (3, (4, 99)), (3, (3, 54)), (3, (6, 75)), (3, (5, 66)), (3, (0, 76)), (3, (9, 63)), (3, (8, 67)), (1, (0, 92)), (9, (5, 59)), (9, (2, 96))]
#
# Running SA with parameters: {'initial_temperature': 700, 'cooling_rate': 0.94, 'max_iterations': 1100}
# SA Results - Parameters: {'initial_temperature': 700, 'cooling_rate': 0.94, 'max_iterations': 1100}
# Best Fitness (Makespan): 3656
# Best Solution: [(4, (7, 67)), (4, (4, 88)), (1, (7, 94)), (5, (2, 80)), (5, (5, 64)), (8, (7, 85)), (0, (0, 86)), (9, (8, 67)), (3, (3, 54)), (6, (3, 96)), (7, (4, 98)), (1, (3, 50)), (9, (9, 96)), (7, (6, 73)), (3, (9, 63)), (7, (1, 71)), (2, (0, 83)), (1, (1, 82)), (2, (5, 85)), (3, (5, 66)), (8, (0, 94)), (6, (8, 97)), (9, (3, 50)), (0, (9, 77)), (8, (9, 97)), (6, (5, 99)), (5, (7, 69)), (5, (8, 80)), (0, (4, 88)), (6, (1, 86)), (0, (6, 94)), (4, (2, 67)), (3, (7, 94)), (3, (0, 76)), (2, (1, 65)), (0, (5, 99)), (8, (5, 58)), (4, (6, 95)), (5, (1, 99)), (7, (8, 95)), (0, (8, 68)), (0, (1, 67)), (2, (7, 78)), (5, (9, 62)), (6, (0, 95)), (0, (7, 99)), (2, (6, 64)), (6, (2, 66)), (0, (3, 92)), (6, (6, 52)), (6, (7, 50)), (2, (8, 61)), (3, (2, 68)), (0, (2, 89)), (1, (6, 69)), (1, (9, 63)), (4, (8, 95)), (3, (1, 61)), (9, (4, 81)), (1, (2, 94)), (7, (0, 62)), (5, (3, 79)), (4, (1, 86)), (9, (2, 96)), (2, (4, 85)), (8, (8, 93)), (1, (4, 75)), (6, (9, 71)), (8, (3, 81)), (7, (3, 82)), (3, (4, 99)), (3, (8, 67)), (7, (2, 51)), (3, (6, 75)), (6, (4, 97)), (9, (7, 56)), (5, (6, 66)), (1, (0, 92)), (5, (0, 88)), (9, (0, 59)), (4, (9, 82)), (9, (5, 59)), (9, (6, 58)), (8, (2, 90)), (8, (6, 71)), (9, (1, 82)), (2, (9, 83)), (7, (9, 79)), (5, (4, 81)), (7, (5, 94)), (7, (7, 85)), (1, (5, 72)), (2, (2, 55)), (8, (1, 66)), (1, (8, 66)), (4, (3, 69)), (2, (3, 77)), (8, (4, 76)), (4, (5, 68)), (4, (0, 99))]
